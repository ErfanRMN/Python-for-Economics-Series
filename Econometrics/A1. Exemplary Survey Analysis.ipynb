# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import statsmodels.api as sm
import researchpy as rs

# %% [markdown]
# # <font face="gotham" color="navy"> Importing & Cleaning Data

# %%
data0=pd.read_excel("Final_Data.xlsx")

# %%
data0.head()
# Out:
#        CODE0  Total_Score_Before  Raftare_Mali_Before  Negareshe_Mali_Before  \
# 0  810896047                  22                   30                     33
# 1  810197456                  18                   25                     33
# 2  810998117                  21                   19                     35
# 3  810399077                  15                   18                     38
# 4  430800033                  28                   38                     52
#
#    Total_Score_Before_Percentile  Raftare_Mali_Before_Percentile  \
# 0                      66.666667                       66.666667
# 1                      54.545455                       55.555556
# 2                      63.636364                       42.222222
# 3                      45.454545                       40.000000
# 4                      84.848485                       84.444444
#
#    Negareshe_Mali_Before_Percentile  Q2A  Q2B  Q2C  ...  Q64  Q65  Q66  \
# ...

# %%
data0.columns
# Out:
# Index(['CODE0', 'Total_Score_Before', 'Raftare_Mali_Before',
#        'Negareshe_Mali_Before', 'Total_Score_Before_Percentile',
#        'Raftare_Mali_Before_Percentile', 'Negareshe_Mali_Before_Percentile',
#        'Q2A', 'Q2B', 'Q2C', 'Q2D', 'Q2E', 'Q8', 'Q55', 'Q56_SEN', 'Q56', 'Q57',
#        'Q58', 'Q59', 'Q60_GPA', 'Q61_YEAR_IN_UNI', 'Q62', 'Q63', 'Q64', 'Q65',
#        'Q66', 'Q67_INCOME', 'Total_Score_After', 'Raftare_Mali_After',
#        'Negareshe_Mali_After', 'Total_Score_After_Percentile',
#        'Raftare_Mali_After_Percentile', 'Negareshe_Mali_After_Percentile'],
#       dtype='object')

# %% [markdown]
# # <font face="gotham" color="navy"> Visualization

# %%
data0.plot(y='Total_Score_Before_Percentile',kind='hist')
plt.grid()

data0.plot(y='Total_Score_After_Percentile', kind='hist')
plt.grid()

# %%
data0.plot(y='Raftare_Mali_Before_Percentile',kind='hist')
plt.grid()

data0.plot(y='Negareshe_Mali_Before_Percentile', kind='hist')
plt.grid()

data0.plot(y='Raftare_Mali_After_Percentile',kind='hist')
plt.grid()

data0.plot(y='Negareshe_Mali_After_Percentile', kind='hist')
plt.grid()

# %%
data0.plot(y='Q67_INCOME', kind='density',xlim=(0,6))
plt.grid()

data0.plot(y='Q60_GPA', kind='density',xlim=(0,6))
plt.grid()

data0.plot(y='Q56_SEN', kind='density',xlim=(0,4))
plt.grid()

data0.plot(y='Q61_YEAR_IN_UNI',kind='density',xlim=(0,6))
plt.grid()

# %% [markdown]
# # <font face="gotham" color="navy"> Regression Analysis I

# %%
indep='Q2A +'+ 'Q2B +'+ 'Q2C +'+ 'Q2D +'+ 'Q2E +' + 'Q8 +'+ 'Q55 +'+ 'Q56 +'+ 'Q57 +'+ 'Q58 +'+ 'Q59 +'+ 'Q60_GPA +'+ 'Q61_YEAR_IN_UNI +'+ 'Q62 +'+ 'Q63 +'+ 'Q64 +'+ 'Q65 +'+ 'Q66 +'+ 'Q67_INCOME'

# %%
m11=smf.gls('Total_Score_Before ~ '+indep, data0).fit()

m11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ...
# Dep. Variable:     Total_Score_Before   R-squared:                       0.072
# Model:                            GLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     5.261
# Date:                Sat, 27 Jan 2024   Prob (F-statistic):           1.93e-12
# Time:                        10:38:45   Log-Likelihood:                -3535.0
# No. Observations:                1316   AIC:                             7110.
# Df Residuals:                    1296   BIC:                             7214.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
m12=smf.gls('Raftare_Mali_Before ~ '+indep, data0).fit()

m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              GLS Regression Results
# ...
# Dep. Variable:     Raftare_Mali_Before   R-squared:                       0.073
# Model:                             GLS   Adj. R-squared:                  0.059
# Method:                  Least Squares   F-statistic:                     5.375
# Date:                 Sat, 27 Jan 2024   Prob (F-statistic):           8.30e-13
# Time:                         10:38:46   Log-Likelihood:                -4035.5
# No. Observations:                 1316   AIC:                             8111.
# Df Residuals:                     1296   BIC:                             8215.
# Df Model:                           19
# Covariance Type:             nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
m13=smf.gls('Negareshe_Mali_Before ~ '+ indep, data0).fit()

m13.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               GLS Regression Results
# ...
# Dep. Variable:     Negareshe_Mali_Before   R-squared:                       0.087
# Model:                               GLS   Adj. R-squared:                  0.074
# Method:                    Least Squares   F-statistic:                     6.508
# Date:                   Sat, 27 Jan 2024   Prob (F-statistic):           1.80e-16
# Time:                           10:38:46   Log-Likelihood:                -3824.3
# No. Observations:                   1316   AIC:                             7689.
# Df Residuals:                       1296   BIC:                             7792.
# Df Model:                             19
# Covariance Type:               nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# # <font face="gotham" color="navy"> Regression Analysis II

# %%
m21=smf.gls('Total_Score_After ~ '+indep, data0).fit()

m21.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ...
# Dep. Variable:      Total_Score_After   R-squared:                       0.052
# Model:                            GLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     3.709
# Date:                Sat, 27 Jan 2024   Prob (F-statistic):           1.31e-07
# Time:                        10:38:47   Log-Likelihood:                -3803.9
# No. Observations:                1316   AIC:                             7648.
# Df Residuals:                    1296   BIC:                             7751.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
m22=smf.gls('Raftare_Mali_After ~ '+indep, data0).fit()

m22.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ...
# Dep. Variable:     Raftare_Mali_After   R-squared:                       0.155
# Model:                            GLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     12.52
# Date:                Sat, 27 Jan 2024   Prob (F-statistic):           3.71e-36
# Time:                        10:38:48   Log-Likelihood:                -4038.8
# No. Observations:                1316   AIC:                             8118.
# Df Residuals:                    1296   BIC:                             8221.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
m23=smf.gls('Negareshe_Mali_After ~ '+indep, data0).fit()

m23.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              GLS Regression Results
# ...
# Dep. Variable:     Negareshe_Mali_After   R-squared:                       0.039
# Model:                              GLS   Adj. R-squared:                  0.025
# Method:                   Least Squares   F-statistic:                     2.754
# Date:                  Sat, 27 Jan 2024   Prob (F-statistic):           7.51e-05
# Time:                          10:38:48   Log-Likelihood:                -3667.3
# No. Observations:                  1316   AIC:                             7375.
# Df Residuals:                      1296   BIC:                             7478.
# Df Model:                            19
# Covariance Type:              nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# # <font face="gotham" color="navy"> Comparative Analysis

# %%
rs.ttest(data0['Total_Score_After'],data0['Total_Score_Before'],paired=True)
# Out:
# (             Variable       N       Mean        SD        SE  95% Conf.  \
#  0   Total_Score_After  1316.0  21.965046  4.474549  0.123345  21.723071
#  1  Total_Score_Before  1316.0  19.132979  3.686759  0.101629  18.933606
#  2                diff  1316.0   2.832067  4.576339  0.126151   2.584588
#
#      Interval
#  0  22.207020
#  1  19.332351
#  2   3.079546  ,
#                                 Paired samples t-test    results
#  0  Difference (Total_Score_After - Total_Score_Be...     2.8321
#  1                              Degrees of freedom =   1315.0000
#  2                                               t =     22.4498
#  3                           Two side test p value =      0.0000
#  4                          Difference < 0 p value =      0.0000
#  5                          Difference > 0 p value =      1.0000
#  6                                       Cohen's d =      0.6940
#  7                                       Hedge's g =      0.6938
# ...

# %%
rs.ttest(data0['Raftare_Mali_After'],data0['Raftare_Mali_Before'],paired=True)
# Out:
# (              Variable       N       Mean        SD        SE  95% Conf.  \
#  0   Raftare_Mali_After  1316.0  28.519757  5.667094  0.156219  28.213292
#  1  Raftare_Mali_Before  1316.0  25.614742  5.397061  0.148775  25.322880
#  2                 diff  1316.0   2.905015  5.019894  0.138378   2.633550
#
#      Interval
#  0  28.826222
#  1  25.906604
#  2   3.176481  ,
#                                 Paired samples t-test    results
#  0  Difference (Raftare_Mali_After - Raftare_Mali_...     2.9050
#  1                              Degrees of freedom =   1315.0000
#  2                                               t =     20.9934
#  3                           Two side test p value =      0.0000
#  4                          Difference < 0 p value =      0.0000
#  5                          Difference > 0 p value =      1.0000
#  6                                       Cohen's d =      0.5251
#  7                                       Hedge's g =      0.5250
# ...

# %%
rs.ttest(data0['Negareshe_Mali_After'],data0['Negareshe_Mali_Before'],paired=True)
# Out:
# (                Variable       N       Mean        SD        SE  95% Conf.  \
#  0   Negareshe_Mali_After  1316.0  37.918693  4.006677  0.110448  37.702020
#  1  Negareshe_Mali_Before  1316.0  34.004559  4.632172  0.127690  33.754061
#  2                   diff  1316.0   3.914134  4.733611  0.130486   3.658150
#
#      Interval
#  0  38.135366
#  1  34.255058
#  2   4.170118  ,
#                                 Paired samples t-test    results
#  0  Difference (Negareshe_Mali_After - Negareshe_M...     3.9141
#  1                              Degrees of freedom =   1315.0000
#  2                                               t =     29.9965
#  3                           Two side test p value =      0.0000
#  4                          Difference < 0 p value =      0.0000
#  5                          Difference > 0 p value =      1.0000
#  6                                       Cohen's d =      0.9062
#  7                                       Hedge's g =      0.9059
# ...

# %% [markdown]
# # <font face="gotham" color="navy"> ANOVA

# %%
rs.anova('Total_Score_Before ~ '+indep,data0).results()
# Out:
#  Note: Effect size values for factors are partial.
# (                          0
#  Number of obs =   1316.0000
#  Root MSE =           3.5783
#  R-squared =          0.0716
#  Adj R-squared =      0.0580,
#               Source Sum of Squares Degrees of Freedom Mean Squares  F value  \
#  0             Model      1279.8896                 19      67.3626   5.2611
#  1
#  2               Q2A         3.6015                1.0       3.6015   0.2813
#  3               Q2B       156.8794                1.0     156.8794  12.2525
#  4               Q2C        75.8196                1.0      75.8196   5.9216
#  5               Q2D         3.3254                1.0       3.3254   0.2597
#  6               Q2E         3.5232                1.0       3.5232   0.2752
#  7                Q8         0.0882                1.0       0.0882   0.0069
#  8               Q55       176.0907                1.0     176.0907  13.7529
# ...

# %%
rs.anova('Raftare_Mali_Before ~ '+indep,data0).results()
# Out:
#  Note: Effect size values for factors are partial.
# (                          0
#  Number of obs =   1316.0000
#  Root MSE =           5.2341
#  R-squared =          0.0730
#  Adj R-squared =      0.0595,
#               Source Sum of Squares Degrees of Freedom Mean Squares  F value  \
#  0             Model      2798.0414                 19     147.2653   5.3754
#  1
#  2               Q2A       315.7109                1.0     315.7109  11.5238
#  3               Q2B         905.43                1.0       905.43  33.0493
#  4               Q2C         0.0979                1.0       0.0979   0.0036
#  5               Q2D       590.4775                1.0     590.4775  21.5532
#  6               Q2E         5.7841                1.0       5.7841   0.2111
#  7                Q8       130.9118                1.0     130.9118   4.7784
#  8               Q55         83.857                1.0       83.857   3.0609
# ...

# %%
rs.anova('Negareshe_Mali_Before ~ '+indep,data0).results()
# Out:
#  Note: Effect size values for factors are partial.
# (                          0
#  Number of obs =   1316.0000
#  Root MSE =           4.4582
#  R-squared =          0.0871
#  Adj R-squared =      0.0737,
#               Source Sum of Squares Degrees of Freedom Mean Squares  F value  \
#  0             Model      2457.7315                 19     129.3543   6.5083
#  1
#  2               Q2A       333.3908                1.0     333.3908  16.7742
#  3               Q2B       223.1971                1.0     223.1971  11.2299
#  4               Q2C        64.0735                1.0      64.0735   3.2238
#  5               Q2D       350.8438                1.0     350.8438  17.6524
#  6               Q2E        20.0943                1.0      20.0943    1.011
#  7                Q8       875.6743                1.0     875.6743  44.0587
#  8               Q55        12.4277                1.0      12.4277   0.6253
# ...

# %%
rs.anova('Total_Score_After ~ '+indep,data0).results()
# Out:
#  Note: Effect size values for factors are partial.
# (                          0
#  Number of obs =   1316.0000
#  Root MSE =           4.3895
#  R-squared =          0.0516
#  Adj R-squared =      0.0377,
#               Source Sum of Squares Degrees of Freedom Mean Squares  F value  \
#  0             Model      1357.7401                 19        71.46   3.7088
#  1
#  2               Q2A        50.5752                1.0      50.5752   2.6249
#  3               Q2B         5.3763                1.0       5.3763    0.279
#  4               Q2C        55.7817                1.0      55.7817   2.8951
#  5               Q2D       105.0752                1.0     105.0752   5.4535
#  6               Q2E        35.8889                1.0      35.8889   1.8627
#  7                Q8        91.7613                1.0      91.7613   4.7625
#  8               Q55       103.5764                1.0     103.5764   5.3757
# ...

# %%
rs.anova('Raftare_Mali_After ~ '+indep,data0).results()
# Out:
#  Note: Effect size values for factors are partial.
# (                          0
#  Number of obs =   1316.0000
#  Root MSE =           5.2471
#  R-squared =          0.1551
#  Adj R-squared =      0.1427,
#               Source Sum of Squares Degrees of Freedom Mean Squares   F value  \
#  0             Model      6550.4982                 19     344.7631   12.5221
#  1
#  2               Q2A        573.611                1.0      573.611    20.834
#  3               Q2B      2890.9366                1.0    2890.9366  105.0013
#  4               Q2C         0.5339                1.0       0.5339    0.0194
#  5               Q2D       900.1492                1.0     900.1492   32.6942
#  6               Q2E         0.2388                1.0       0.2388    0.0087
#  7                Q8       587.6744                1.0     587.6744   21.3448
#  8               Q55        46.7178                1.0      46.7178    1.6968
# ...

# %%
rs.anova('Negareshe_Mali_After ~ '+indep,data0).results()
# Out:
#  Note: Effect size values for factors are partial.
# (                          0
#  Number of obs =   1316.0000
#  Root MSE =           3.9569
#  R-squared =          0.0388
#  Adj R-squared =      0.0247,
#               Source Sum of Squares Degrees of Freedom Mean Squares  F value  \
#  0             Model       819.2332                 19      43.1175   2.7539
#  1
#  2               Q2A       205.8094                1.0     205.8094  13.1451
#  3               Q2B        37.8108                1.0      37.8108    2.415
#  4               Q2C         4.3768                1.0       4.3768   0.2795
#  5               Q2D       147.8943                1.0     147.8943   9.4461
#  6               Q2E         0.0005                1.0       0.0005      0.0
#  7                Q8        94.9341                1.0      94.9341   6.0635
#  8               Q55         0.0163                1.0       0.0163    0.001
# ...
