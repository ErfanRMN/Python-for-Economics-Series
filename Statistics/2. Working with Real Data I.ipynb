# %% [markdown]
# ![download.png](attachment:download.png)

# %%
import pandas as pd

# %%
gdp = pd.read_excel('P_Data_Extract_From_World_Development_Indicators1.xlsx', index_col=0)

# %%
gdp.head()
# Out:
#                                                  Country Code  \
# Country Name
# Australia                                                 AUS
# NaN                                                       NaN
# NaN                                                       NaN
# NaN                                                       NaN
# Data from database: World Development Indicators          NaN
#
#                                                         Series Name  \
# Country Name
# Australia                                         GDP (current US$)
# NaN                                                             NaN
# NaN                                                             NaN
# NaN                                                             NaN
# Data from database: World Development Indicators                NaN
#
#                                                      Series Code  \
# Country Name
# Australia                                         NY.GDP.MKTP.CD
# ...

# %%
gdp.columns
# Out:
# Index(['Country Code', 'Series Name', 'Series Code', '1997 [YR1997]',
#        '1998 [YR1998]', '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]',
#        '2002 [YR2002]', '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]',
#        '2006 [YR2006]', '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]', '2021 [YR2021]'],
#       dtype='object')

# %%
gdp.dropna(inplace=True)

# %%
gdp.head()
# Out:
#              Country Code        Series Name     Series Code  1997 [YR1997]  \
# Country Name
# Australia             AUS  GDP (current US$)  NY.GDP.MKTP.CD   4.356143e+11
#
#               1998 [YR1998]  1999 [YR1999]  2000 [YR2000]  2001 [YR2001]  \
# Country Name
# Australia      3.996609e+11   3.893896e+11   4.158513e+11   3.793582e+11
#
#               2002 [YR2002]  2003 [YR2003]  ...  2012 [YR2012]  2013 [YR2013]  \
# Country Name                                ...
# Australia      3.955808e+11   4.674980e+11  ...   1.546892e+12   1.576380e+12
#
#               2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# Country Name
# Australia      1.467545e+12   1.350616e+12   1.206535e+12   1.326516e+12
#
#               2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  2021 [YR2021]
# Country Name
# Australia      1.428289e+12   1.392228e+12   1.326901e+12   1.552667e+12
#
# [1 rows x 28 columns]

# %%
gdp.drop(['Country Code', 'Series Name', 'Series Code'],axis=1, inplace=True)

# %%
gdp.head(3)
# Out:
#               1997 [YR1997]  1998 [YR1998]  1999 [YR1999]  2000 [YR2000]  \
# Country Name
# Australia      4.356143e+11   3.996609e+11   3.893896e+11   4.158513e+11
#
#               2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  2004 [YR2004]  \
# Country Name
# Australia      3.793582e+11   3.955808e+11   4.674980e+11   6.143264e+11
#
#               2005 [YR2005]  2006 [YR2006]  ...  2012 [YR2012]  2013 [YR2013]  \
# Country Name                                ...
# Australia      6.953285e+11   7.479066e+11  ...   1.546892e+12   1.576380e+12
#
#               2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# Country Name
# Australia      1.467545e+12   1.350616e+12   1.206535e+12   1.326516e+12
#
#               2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  2021 [YR2021]
# Country Name
# Australia      1.428289e+12   1.392228e+12   1.326901e+12   1.552667e+12
#
# [1 rows x 25 columns]

# %%
gdp.describe()
# Out:
#        1997 [YR1997]  1998 [YR1998]  1999 [YR1999]  2000 [YR2000]  \
# count   1.000000e+00   1.000000e+00   1.000000e+00   1.000000e+00
# mean    4.356143e+11   3.996609e+11   3.893896e+11   4.158513e+11
# std              NaN            NaN            NaN            NaN
# min     4.356143e+11   3.996609e+11   3.893896e+11   4.158513e+11
# 25%     4.356143e+11   3.996609e+11   3.893896e+11   4.158513e+11
# 50%     4.356143e+11   3.996609e+11   3.893896e+11   4.158513e+11
# 75%     4.356143e+11   3.996609e+11   3.893896e+11   4.158513e+11
# max     4.356143e+11   3.996609e+11   3.893896e+11   4.158513e+11
#
#        2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  2004 [YR2004]  \
# count   1.000000e+00   1.000000e+00   1.000000e+00   1.000000e+00
# mean    3.793582e+11   3.955808e+11   4.674980e+11   6.143264e+11
# std              NaN            NaN            NaN            NaN
# min     3.793582e+11   3.955808e+11   4.674980e+11   6.143264e+11
# ...

# %%
gdp1 = gdp.T

# %%
gdp1.describe()
# Out:
# Country Name     Australia
# count         2.500000e+01
# mean          9.800319e+11
# std           4.474055e+11
# min           3.793582e+11
# 25%           4.674980e+11
# 50%           1.055643e+12
# 75%           1.392228e+12
# max           1.576380e+12

# %%
gdp.T.std(ddof=1)
# Out:
# Country Name
# Australia    4.474055e+11
# dtype: float64

# %%
gdp.T.plot()
# Out:
# <AxesSubplot:>

# %%
gdp.T.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
gdp.T.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
gdp.T.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
gdp.T.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
gdp.T.plot(kind='hist',bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
gdp.loc["Australia",'2000 [YR2000]':'2021 [YR2021]'].plot(kind="box")
# Out:
# <AxesSubplot:>
